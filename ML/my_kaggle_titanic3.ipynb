# %%
import pandas as pd
import numpy as np
import array

# %%
# %ls titanic
# Out:
# 1.csv         20181223_2.csv  20181223_4.csv  gender_submission.csv  train.csv
# 20181223.csv  20181223_3.csv  20181223_5.csv  test.csv

# %%
train = pd.read_csv('titanic/train.csv')
test = pd.read_csv('titanic/test.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print ( len( train['Age'].isnull().values ) )
# Out:
# 891

# %%
arr = []
for s in train['Sex'].values:
    if(s=='male') :
        arr.append(1)
    else:
        arr.append(0)
len(arr)
# Out:
# 891

# %%
train['Sex'] = arr

# %%
train[ ['Sex'] ].shape
# Out:
# (891, 1)

# %%
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris    1  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# Age 값이 Null 값이면 전체 값의 평균 값을 대입한다.
import math 

n_of_n = train['Age'].isnull().count()   # all
n_of_t = train['Age'].count()            # not null count

sum = 0
arr = []
for s in train['Age'].values:
    if(math.isnan(s)) :
        arr.append(0)
    else:
        arr.append(s)
        sum = sum + s
        
avg = sum / n_of_t
avg = round(avg,0)
print(sum)
print(avg)

arr2 = []
for i in arr:
    if(i==0): 
        arr2.append(avg)
    else:
        arr2.append(i)
        
train['Age'] = arr2
# Out:
# 21205.17
# 30.0

# %%
mycols = train.columns
mycols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
mycols = train.columns
mycols = np.delete(train.columns, [0,1,3,8,10,11])

# %%
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris    1  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
mycols
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# X: 
# Y: 
X = train[mycols].values
Y = train['Survived'].values

# %%
df_X = pd.DataFrame(X, columns=mycols)
df_Y = pd.DataFrame(Y, columns=['Survivied'])

# %%
df_X.head(1)
# Out:
#    Pclass  Sex   Age  SibSp  Parch  Fare
# 0     3.0  1.0  22.0    1.0    0.0  7.25

# %%
TR_df = pd.DataFrame(X, columns = [mycols])

# %%
TR_df ['Survived'] = Y
TR_df.head(1)
# Out:
#   Pclass  Sex   Age SibSp Parch  Fare Survived
# 0    3.0  1.0  22.0   1.0   0.0  7.25        0

# %%
# %matplotlib inline
TR_df = pd.DataFrame(X, columns = [mycols])
# 데이터프레임을 사용해 y_train에 따라 색으로 구분된 산점도 행렬을 만듭니다.
pd.plotting.scatter_matrix(TR_df, c=Y, figsize=(15, 15), marker='o',
hist_kwds={'bins': 20}, s=60, alpha=.8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f199b462a58>,
# ...
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X,Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
# %ls titanic/
# Out:
# 1.csv         20181223_2.csv  20181223_4.csv  gender_submission.csv  train.csv
# 20181223.csv  20181223_3.csv  20181223_5.csv  test.csv

# %%
test = pd.read_csv('titanic/test.csv')
T = test[mycols]

# %%
T.isnull().sum()
# Out:
# Pclass     0
# Sex        0
# Age       86
# SibSp      0
# Parch      0
# Fare       1
# dtype: int64

# %%
# Age 값이 Null 값이면 전체 값의 평균 값을 대입한다.
import math 

n_of_n = train['Age'].isnull().count()   # all
n_of_t = train['Age'].count()            # not null count

sum = 0
arr = []
for s in train['Age'].values:
    if(math.isnan(s)) :
        arr.append(0)
    else:
        arr.append(s)
        sum = sum + s
        
avg = sum / n_of_t
avg = round(avg,0)
print(sum)
print(avg)

arr2 = []
for i in T['Age'].values:
        if(math.isnan(i)):
            arr2.append(avg)
        else:
            arr2.append(i)
            
len(arr2)

T['Age'] = arr2
# Out:
# 26515.17
# 30.0

# %%
arr = []
for s in T['Sex'].values:
    if(s=='male') :
        arr.append(1)
    else:
        arr.append(0)
len(arr)
# Out:
# 418

# %%
T['Sex'] = arr

# %%
T.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      0
# dtype: int64

# %%
T = T.fillna(0)  #귀찮아서 Fare는 0으로 체움

# %%
Y_pred = knn.predict(T.values)
Y_pred
Y_pred.shape
# Out:
# (418,)

# %%
sub = pd.read_csv('titanic/gender_submission.csv')

# %%
sub.shape
# Out:
# (418, 2)

# %%
sub['Survived'] = Y_pred

# %%
from datetime import date
dt = date.today()
tstr = dt.strftime('%Y%m%d_7')
sfname = 'titanic/' + tstr + '.csv'
sfname


sub.to_csv(sfname,index=False)

# %%
# %ls titanic
# Out:
# 1.csv           20181223_3.csv  20181223_6.csv         test.csv
# 20181223.csv    20181223_4.csv  20181223_7.csv         train.csv
# 20181223_2.csv  20181223_5.csv  gender_submission.csv
